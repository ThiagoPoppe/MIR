# %% [markdown]
# # Questão 01)

# %%
from music21 import *

mystream = stream.Stream([
    clef.BassClef(),
    note.Note('C4', quarterLength=2),
    note.Note('F#4'),
    note.Note('Bb2')
])

# Ao executarmos esse comando teremos a mesma partitura do enunciado.
mystream.show()

# %%
mystream.plot('pianoroll')
# Out:
# <music21.graph.plot.HorizontalBarPitchSpaceOffset for <music21.stream.Stream 0x7fb6d4b4ffa0>>

# %% [markdown]
# # Questão 02)

# %%
print('Frequência da nota C4: {:.2f}Hz'.format(note.Note('C4').pitch.frequency))
print('Frequência da nota F#4: {:.2f}Hz'.format(note.Note('F#4').pitch.frequency))
print('Frequência da nota Bb2: {:.2f}Hz'.format(note.Note('Bb2').pitch.frequency))
# Out:
# Frequência da nota C4: 261.63Hz
# Frequência da nota F#4: 369.99Hz
# Frequência da nota Bb2: 116.54Hz

# %% [markdown]
# # Questão 04)

# %%
import numpy as np
from scipy.signal import chirp
import matplotlib.pyplot as plt

def generate_chirp_signal(f0, ft, T):
    fs = 2.5 * ft
    n_samples = int(fs * T)
    
    t = np.linspace(0, T, n_samples)
    x = chirp(t, f0=f0, t1=T, f1=ft, method='linear')
    
    return x, t

signal, t = generate_chirp_signal(f0=15, ft=150, T=1000)

plt.xlabel('Time [sec]')
plt.plot(t, signal)
plt.show()

# %%
from scipy.fft import fft
fft_values = np.abs(fft(signal))

plt.title('FFT of chirp signal')
plt.xlabel('Frequency (index k)')
plt.plot(fft_values)
plt.show()

# %% [markdown]
# # Questão 05)

# %%
from scipy.signal import stft
f, t, Zxx = stft(signal, window='hann', nperseg=10)

plt.figure(figsize=(10, 5))
plt.pcolormesh(t, f, np.log(np.abs(Zxx)), shading='gouraud')
plt.title('STFT Magnitude')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
f, t, Zxx = stft(signal, window='hann', nperseg=100)

plt.figure(figsize=(10, 5))
plt.pcolormesh(t, f, np.log(np.abs(Zxx)), shading='gouraud')
plt.title('STFT Magnitude')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
